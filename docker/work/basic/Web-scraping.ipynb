# %%
import pandas as pd

# %%
url1 = 'https://en.wikipedia.org/wiki/S%26P_500'

# %%
list_df = pd.read_html(url1)

# %%
list_df
# Out:
# [                                 0  \
#  0  S&P 500 Index from 1950 to 2016
#  1                       Foundation
#  2                         Operator
#  3                        Exchanges
#  4                     Constituents
#  5                             Type
#  6                       Market cap
#  7                 Weighting method
#  8                  Related indices
#  9                          Website
#
#                                                    1
#  0                   S&P 500 Index from 1950 to 2016
#  1                    March 4, 1957; 64 years ago[1]
#  2                          S&P Dow Jones Indices[2]
#  3                   NYSE, NASDAQ, Cboe BZX Exchange
#  4                                            505[2]
#  5                                      Large-cap[2]
#  6          US$38.2 trillion(as of June 30, 2021)[2]
#  7             Free-float capitalization-weighted[3]
#  8                    S&P 1500S&P Global 1200S&P 100
# ...

# %%
len(list_df)
# Out:
# 12

# %%
list_df[0]
# Out:
#                                  0  \
# 0  S&P 500 Index from 1950 to 2016
# 1                       Foundation
# 2                         Operator
# 3                        Exchanges
# 4                     Constituents
# 5                             Type
# 6                       Market cap
# 7                 Weighting method
# 8                  Related indices
# 9                          Website
#
#                                                   1
# 0                   S&P 500 Index from 1950 to 2016
# 1                    March 4, 1957; 64 years ago[1]
# 2                          S&P Dow Jones Indices[2]
# 3                   NYSE, NASDAQ, Cboe BZX Exchange
# 4                                            505[2]
# 5                                      Large-cap[2]
# 6          US$38.2 trillion(as of June 30, 2021)[2]
# 7             Free-float capitalization-weighted[3]
# 8                    S&P 1500S&P Global 1200S&P 100
# ...

# %%
list_df[1]
# Out:
#       Year  Change in Index  Total Annual Return Including Dividends  \
# 0     1970            0.10%                                    4.01%
# 1     1971           10.79%                                   14.31%
# 2     1972           15.63%                                   18.98%
# 3     1973          −17.37%                                  −14.66%
# 4     1974          −29.72%                                  −26.47%
# 5     1975           31.55%                                   37.20%
# 6     1976           19.15%                                   23.84%
# 7     1977          −11.50%                                   −7.18%
# 8     1978            1.06%                                    6.56%
# 9     1979           12.31%                                   18.44%
# 10    1980           25.77%                                   32.50%
# 11    1981           −9.73%                                   −4.92%
# 12    1982           14.76%                                   21.55%
# ...

# %%
import requests
